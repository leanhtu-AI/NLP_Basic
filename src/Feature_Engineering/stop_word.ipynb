# %%
import spacy

from spacy.lang.en.stop_words import STOP_WORDS

STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
len(STOP_WORDS)
# Out:
# 326

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp("This is the our pen and you are not going to touch this.")

for token in doc:
    if token.is_stop:
        print(token)
# Out:
# This
# is
# the
# our
# and
# you
# are
# not
# to
# this

# %%
def preprocess(text):
    doc = nlp(text)
    lst = [token.text for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(lst)

# %%
preprocess("This is the our pen and you are not going to touch this.")
# Out:
# 'pen going touch'

# %%
import pandas as pd
df = pd.read_json("C:/Users/FPTSHOP/OneDrive/Documents/JVB_Training/NLP/data/combined.json", lines = True)

# %%
df.shape
# Out:
# (13087, 6)

# %%
df.head()
# Out:
#         id                                              title  \
# 0     None       Convicted Bomb Plotter Sentenced to 30 Years
# 1  12-919   $1 Million in Restitution Payments Announced t...
# 2  11-1002  $1 Million Settlement Reached for Natural Reso...
# 3   10-015  10 Las Vegas Men Indicted \r\nfor Falsifying V...
# 4   18-898  $100 Million Settlement Will Speed Cleanup Wor...
#
#                                             contents  \
# 0  PORTLAND, Oregon. – Mohamed Osman Mohamud, 23,...
# 1    WASHINGTON – North Carolina’s Waccamaw River...
# 2        BOSTON– A $1-million settlement has been...
# 3    WASHINGTON—A federal grand jury in Las Vegas...
# 4  The U.S. Department of Justice, the U.S. Envir...
#
#                         date         topics  \
# 0  2014-10-01T00:00:00-04:00             []
# 1  2012-07-25T00:00:00-04:00             []
# 2  2011-08-03T00:00:00-04:00             []
# 3  2010-01-08T00:00:00-05:00             []
# ...

# %%
df = df[df['topics'].str.len() != 0]

# %%
df.shape
# Out:
# (4688, 6)

# %%
df.head()
# Out:
#          id                                              title  \
# 4    18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7   14-1412  14 Indicted in Connection with New England Com...
# 19  17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22  15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23  17-1404  21st Century Oncology to Pay $26 Million to Se...
#
#                                              contents  \
# 4   The U.S. Department of Justice, the U.S. Envir...
# 7   A 131-count criminal indictment was unsealed t...
# 19  The United States Attorney’s Office for the Mi...
# 22  21st Century Oncology LLC, has agreed to pay $...
# 23  21st Century Oncology Inc. and certain of its ...
#
#                          date                                 topics  \
# 4   2018-07-09T00:00:00-04:00                          [Environment]
# 7   2014-12-17T00:00:00-05:00                  [Consumer Protection]
# ...

# %%
len(df.contents.iloc[3])
# Out:
# 4398

# %%
df =df.head(100)
df.shape
# Out:
# (100, 6)

# %%
df['new_content'] = df['contents'].apply(preprocess)

# %%
df
# Out:
#           id                                              title  \
# 4     18-898  $100 Million Settlement Will Speed Cleanup Wor...
# 7    14-1412  14 Indicted in Connection with New England Com...
# 19   17-1419  2017 Southeast Regional Animal Cruelty Prosecu...
# 22   15-1562  21st Century Oncology to Pay $19.75 Million to...
# 23   17-1404  21st Century Oncology to Pay $26 Million to Se...
# ..       ...                                                ...
# 316  15-1359  Alaska Plastic Surgeon Convicted of Wire Fraud...
# 318   16-396  Alaska Plastic Surgeon Sentenced to Prison for...
# 321   17-736  Alaskan Commercial Fishing Couple Charged with...
# 322   18-717  Alaskan Husband And Wife Plead Guilty To Willf...
# 324  16-1345        Alaskan Oncologist Indicted for Tax Evasion
#
#                                               contents  \
# 4    The U.S. Department of Justice, the U.S. Envir...
# 7    A 131-count criminal indictment was unsealed t...
# ...

# %%
print(len(df.contents.iloc[3]),"\n",len(df.new_content.iloc[3]))
# Out:
# 4398
#  3344

# %% [markdown]
# ### **Exercise**

# %% [markdown]
# Exercise1:
#
# From a Given Text, Count the number of stop words in it.
# Print the percentage of stop word tokens compared to all tokens in a given text.

# %%
text = '''
Thor: Love and Thunder is a 2022 American superhero film based on Marvel Comics featuring the character Thor, produced by Marvel Studios and 
distributed by Walt Disney Studios Motion Pictures. It is the sequel to Thor: Ragnarok (2017) and the 29th film in the Marvel Cinematic Universe (MCU).
The film is directed by Taika Waititi, who co-wrote the script with Jennifer Kaytin Robinson, and stars Chris Hemsworth as Thor alongside Christian Bale, Tessa Thompson,
Jaimie Alexander, Waititi, Russell Crowe, and Natalie Portman. In the film, Thor attempts to find inner peace, but must return to action and recruit Valkyrie (Thompson),
Korg (Waititi), and Jane Foster (Portman)—who is now the Mighty Thor—to stop Gorr the God Butcher (Bale) from eliminating all gods.
'''

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(text)
count = 0
total = 0
for token in doc:
    if token.is_stop:
        count +=1
    total +=1    
print("Num of stop words:",count)
print("Percentage of stop word", (count / total) *100)
# Out:
# Num of stop words: 40
# Percentage of stop word 25.0

# %%
def preprocess(text):
    doc = nlp(text)
    no_stop_words = [token.text for token in doc if not token.is_stop]
    return " ".join(no_stop_words)

# %%
nlp.vocab['not'].is_stop = False

# %%
preprocess("this is not good enough.")
# Out:
# 'not good .'

# %%
preprocess("this is good enough")
# Out:
# 'good'
